# %%
import numpy as np
import pandas as pd
from datetime import datetime, date

# %%
pacientes1 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case1\patients.csv')
imunidades1 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case1\immunizations.csv')
condicoes1 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case1\conditions.csv')

pacientes2 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case2\patients.csv')
imunidades2 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case2\immunizations.csv')
condicoes2 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case2\conditions.csv')

pacientes3 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case3\patients.csv')
imunidades3 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case3\immunizations.csv')
condicoes3 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case3\conditions.csv')

pacientes4 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case4\patients.csv')
imunidades4 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case4\immunizations.csv')
condicoes4 = pd.read_csv(r'C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\Mestrado\Disciplinas\MO826\Trabalho 2\Case4\conditions.csv')

# %%
im1 = imunidades1[(imunidades1['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose') | (imunidades1['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose') | (imunidades1['DESCRIPTION']=='SARS-COV-2 (COVID-19) vaccine  vector non-replicating  recombinant spike protein-Ad26  preservative free  0.5 mL')] 
im2 = imunidades2[(imunidades2['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose') | (imunidades2['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose') | (imunidades2['DESCRIPTION']=='SARS-COV-2 (COVID-19) vaccine  vector non-replicating  recombinant spike protein-Ad26  preservative free  0.5 mL')]
im3 = imunidades3[(imunidades3['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose') | (imunidades3['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose') | (imunidades3['DESCRIPTION']=='SARS-COV-2 (COVID-19) vaccine  vector non-replicating  recombinant spike protein-Ad26  preservative free  0.5 mL')] 
im4 = imunidades4[(imunidades4['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose') | (imunidades4['DESCRIPTION'] == 'SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose') | (imunidades4['DESCRIPTION']=='SARS-COV-2 (COVID-19) vaccine  vector non-replicating  recombinant spike protein-Ad26  preservative free  0.5 mL')]

# %%
im3
# Out:
#                         DATE                               PATIENT  \
# 27      2021-11-27T11:07:25Z  52cd9de8-20ea-3573-a6cb-892e7654b286
# 34      2021-12-18T11:07:25Z  52cd9de8-20ea-3573-a6cb-892e7654b286
# 49      2021-03-27T20:53:04Z  4b434001-a788-3d75-ad68-06b598f12ff3
# 51      2021-04-24T20:53:04Z  4b434001-a788-3d75-ad68-06b598f12ff3
# 55      2021-03-15T20:08:40Z  e2edb41f-b3b9-3e59-58c3-b18fb2f439bd
# ...                      ...                                   ...
# 172241  2021-03-04T23:08:39Z  f8713a65-e3a3-2385-e078-d2aa4f337f4a
# 172262  2021-04-05T01:06:42Z  b2c8ab12-f8b7-fff8-15d1-0c34b340fba0
# 172263  2021-04-26T01:06:42Z  b2c8ab12-f8b7-fff8-15d1-0c34b340fba0
# 172269  2021-03-08T21:48:36Z  9ac1fdf4-17ba-bae1-004e-ac4a1a01c362
# 172270  2021-04-05T21:48:36Z  9ac1fdf4-17ba-bae1-004e-ac4a1a01c362
#
#                                    ENCOUNTER  CODE  \
# 27      d7f830fa-269c-a95d-4fdb-5e209264ac7f   208
# 34      4f052905-137f-9542-166d-39909935e8e1   208
# ...

# %%
cd1 = condicoes1[(condicoes1['DESCRIPTION'] == 'COVID-19') | (condicoes1['DESCRIPTION'] == 'Suspected COVID-19')]
cd2 = condicoes2[(condicoes2['DESCRIPTION'] == 'COVID-19') | (condicoes2['DESCRIPTION'] == 'Suspected COVID-19')]
cd3 = condicoes3[(condicoes3['DESCRIPTION'] == 'COVID-19') | (condicoes3['DESCRIPTION'] == 'Suspected COVID-19')]
cd4 = condicoes4[(condicoes4['DESCRIPTION'] == 'COVID-19') | (condicoes4['DESCRIPTION'] == 'Suspected COVID-19')]

# %%
fp1 = pacientes1[['Id','BIRTHDATE','DEATHDATE','RACE','ETHNICITY','GENDER']]
fp1=fp1.rename(columns={'Id':'PATIENT'})

fp2 = pacientes2[['Id','BIRTHDATE','DEATHDATE','RACE','ETHNICITY','GENDER']]
fp2=fp2.rename(columns={'Id':'PATIENT'})

fp3 = pacientes3[['Id','BIRTHDATE','DEATHDATE','RACE','ETHNICITY','GENDER']]
fp3=fp3.rename(columns={'Id':'PATIENT'})

fp4 = pacientes4[['Id','BIRTHDATE','DEATHDATE','RACE','ETHNICITY','GENDER']]
fp4=fp4.rename(columns={'Id':'PATIENT'})

# %%
inter1 = pd.merge(fp1,cd1,how='inner',on=['PATIENT'])
inter1.drop_duplicates(['PATIENT'],keep='first',inplace=True)
inter1.drop(['STOP','ENCOUNTER','CODE','DESCRIPTION'],axis=1,inplace = True)

inter2 = pd.merge(fp2,cd2,how='inner',on=['PATIENT'])
inter2.drop_duplicates(['PATIENT'],keep='first',inplace=True)
inter2.drop(['STOP','ENCOUNTER','CODE','DESCRIPTION'],axis=1,inplace = True)

inter3 = pd.merge(fp3,cd3,how='inner',on=['PATIENT'])
inter3.drop_duplicates(['PATIENT'],keep='first',inplace=True)
inter3.drop(['STOP','ENCOUNTER','CODE','DESCRIPTION'],axis=1,inplace = True)

inter4 = pd.merge(fp4,cd4,how='inner',on=['PATIENT'])
inter4.drop_duplicates(['PATIENT'],keep='first',inplace=True)
inter4.drop(['STOP','ENCOUNTER','CODE','DESCRIPTION'],axis=1,inplace = True)

# %%
immun1 = []
for i in inter1['PATIENT']:
    if i in im1['PATIENT'].unique():
        immun1.append(1)
    else:
        immun1.append(0)
inter1['IMMUNIZED'] = immun1

immun2 = []
for i in inter2['PATIENT']:
    if i in im2['PATIENT'].unique():
        immun2.append(1)
    else:
        immun2.append(0)
inter2['IMMUNIZED'] = immun2

immun3 = []
for i in inter3['PATIENT']:
    if i in im3['PATIENT'].unique():
        immun3.append(1)
    else:
        immun3.append(0)
inter3['IMMUNIZED'] = immun3

immun4 = []
for i in inter4['PATIENT']:
    if i in im4['PATIENT'].unique():
        immun4.append(1)
    else:
        immun4.append(0)
inter4['IMMUNIZED'] = immun4

# %%
n1 = list(pd.isnull(inter1['DEATHDATE']))
group1 = []
age1 = []
for i in range(len(n1)):
    a = (datetime.strptime(inter1.iloc[i][6],'%m/%d/%Y') - datetime.strptime(inter1.iloc[i][1],'%Y-%m-%d')).days
    age1.append(a//365)
    if n1[i]:
        group1.append('Lived')
    else:
        diagnose = datetime.strptime(inter1.iloc[i][6],'%m/%d/%Y')
        death = datetime.strptime(str(inter1.iloc[i][2]),'%Y-%m-%d')
        time = (death - diagnose).days
        if time <= 7:
            group1.append(1)
        elif time <= 14:
            group1.append(2)
        elif time <= 21:
            group1.append(3)
        elif time <= 28:
            group1.append(4)

n2 = list(pd.isnull(inter2['DEATHDATE']))
group2 = []
age2=[]
for i in range(len(n2)):
    a = (datetime.strptime(inter2.iloc[i][6],'%Y-%m-%d') - datetime.strptime(inter2.iloc[i][1],'%Y-%m-%d')).days
    age2.append(a//365)
    if n2[i]:
        group2.append('Lived')
    else:
        diagnose = datetime.strptime(inter2.iloc[i][6],'%Y-%m-%d')
        death = datetime.strptime(str(inter2.iloc[i][2]),'%Y-%m-%d')
        time = (death - diagnose).days
        if time <= 7:
            group2.append(1)
        elif time <= 14:
            group2.append(2)
        elif time <= 21:
            group2.append(3)
        elif time <= 28:
            group2.append(4)

n3 = list(pd.isnull(inter3['DEATHDATE']))
group3 = []
age3=[]
for i in range(len(n3)):
    a = (datetime.strptime(inter3.iloc[i][6],'%Y-%m-%d') - datetime.strptime(inter3.iloc[i][1],'%Y-%m-%d')).days
    age3.append(a//365)
    if n3[i]:
        group3.append('Lived')
    else:
        diagnose = datetime.strptime(inter3.iloc[i][6],'%Y-%m-%d')
        death = datetime.strptime(str(inter3.iloc[i][2]),'%Y-%m-%d')
        time = (death - diagnose).days
        if time <= 7:
            group3.append(1)
        elif time <= 14:
            group3.append(2)
        elif time <= 21:
            group3.append(3)
        elif time <= 28:
            group3.append(4)
        else:
            group3.append('Lived')

n4 = list(pd.isnull(inter4['DEATHDATE']))
group4 = []
age4=[]
for i in range(len(n4)):
    a = (datetime.strptime(inter4.iloc[i][6],'%Y-%m-%d') - datetime.strptime(inter4.iloc[i][1],'%Y-%m-%d')).days
    age4.append(a//365)
    if n4[i]:
        group4.append('Lived')
    else:
        diagnose = datetime.strptime(inter4.iloc[i][6],'%Y-%m-%d')
        death = datetime.strptime(str(inter4.iloc[i][2]),'%Y-%m-%d')
        time = (death - diagnose).days
        if time <= 7:
            group4.append(1)
        elif time <= 14:
            group4.append(2)
        elif time <= 21:
            group4.append(3)
        elif time <= 28:
            group4.append(4)
        else:
            group4.append('Lived')
            
inter1['AGE'] = age1
inter2['AGE'] = age2
inter3['AGE'] = age3
inter4['AGE'] = age4
            
inter1['PROG'] = group1
inter2['PROG'] = group2
inter3['PROG'] = group3
inter4['PROG'] = group4

# %%
inter1.to_csv(r"C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\data1.csv", index = False)
inter2.to_csv(r"C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\data2.csv",index = False)
inter3.to_csv(r"C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\data3.csv", index = False)
inter4.to_csv(r"C:\Users\Luan\Luan Dropbox\Luan Silveira\PC\Desktop\data4.csv",index = False)
